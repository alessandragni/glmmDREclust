# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np
from collections import defaultdict
import os
import pickle
import scipy.stats as st

from itertools import combinations
from scipy.stats import chi2

from code.DataGeneration_class import DataGenerationBernoulli
from code.DataGeneration_class import DataGenerationPoisson

# %% [markdown]
# # DATA GENERATION

# %% [markdown]
# ## Bernoulli

# %%
# BERNOULLI GENERATION 

for w in range(0,100):
  
  DG = DataGenerationBernoulli(False, True, 1, sim=True)
  DG.set_parameters()
  eta, y = DG.compute_eta_and_y()

  x1 = DG.fix[0]

  g = []
  j = 1
  for i in y:
    g.append(np.repeat(j, len(i)))
    j = j + 1

  y = np.hstack(y).squeeze()
  x1 = np.hstack(x1).squeeze()
  g = np.hstack(g).squeeze()

  data = {'y': y, 'x1': x1, 'g': g}
  df = pd.DataFrame(data)
  
  filename = 'Bernoulli_' + str(w) +'.csv'

  df.to_csv('output/comparison_state_of_art/Bernoulli_DG_output/' + filename)

# %% [markdown]
# ## Poisson

# %%
# POISSON GENERATION

for w in range(0,100):
  
  DG = DataGenerationPoisson(False, True, 1, sim=True)
  DG.set_parameters()
  eta, y = DG.compute_eta_and_y()

  x1 = DG.fix[0]

  g = []
  j = 1
  for i in y:
    g.append(np.repeat(j, len(i)))
    j = j + 1

  y = np.hstack(y).squeeze()
  x1 = np.hstack(x1).squeeze()
  g = np.hstack(g).squeeze()

  data = {'y': y, 'x1': x1, 'g': g}
  df = pd.DataFrame(data)
  
  filename = 'Poisson_' + str(w) +'.csv'

  df.to_csv('output/comparison_state_of_art/Poisson_DG_output/' + filename)

# %% [markdown]
# # GLMMDRE

# %%
from code.algorithm_alpha import algorithm_alpha

def compute_order(knots):
    if knots.ndim > 1:
        return np.flip(np.argsort(knots[:, 0]))
    else:
        return np.flip(np.argsort(knots))

# %% [markdown]
# ## Bernoulli

# %%
# Bernoulli

results3 = pd.DataFrame(columns=['Sensitivity', 'Specificity', 'Accuracy'])
melt = pd.DataFrame(columns=['variable', 'value'])

for file in os.listdir('output/comparison_state_of_art/Bernoulli_DG_output/'):
  if file.endswith(".csv"):
    cond = True
    while cond:
        try:
            df = pd.read_csv('output/comparison_state_of_art/Bernoulli_DG_output/' + file).iloc[:,1:]

            N = df.g.nunique()
            lengths = np.array(df.groupby('g').count().reset_index().iloc[:,1])
            y = list(df.groupby('g')['y'].apply(np.array).values)

            fix = defaultdict(list)

            fix[0] = df.groupby('g')['x1'].apply(np.array).values.tolist()

            ran_var = False
            ran_int = True
            n_fix = 1
            tol = 0.05
            sim = True

            #ran_var, ran_int, n_fix, sim, tol, model, fix, lengths, y, N
            knots, par, W, hess_ran, hess_fix, modeleval = algorithm_alpha(ran_var, ran_int, n_fix, sim, tol, model = 'B', 
                                                                fix=None, lengths=None, y=None, N=None, t=None)

            x = compute_order(knots)
            knots = knots[x]
            W = W[:, x]

            group = np.array([np.nan if np.sum(W[i,:])==0 else np.argmax(W[i,:]) for i in range(N)])

            if len(knots)==3:
              cond = False
        except:
            pass
    
    df['ran_int'] = df['g'].apply(lambda x: knots[0] if x == 1 or x == 2 else knots[2] if x == 8 or x == 9 or x == 10 else knots[1])

    temp = par * df['x1'] + df['ran_int']
    df['y_pred'] = np.where(np.exp(temp) / (1 + np.exp(temp)) > 0.5, 1, 0)

    # Append rows in Empty Dataframe by adding dictionaries
    new_rows = pd.DataFrame([
    {'variable': 'c1,1', 'value': knots[0]},
    {'variable': 'c1,2', 'value': knots[1]},
    {'variable': 'c1,3', 'value': knots[2]},
    {'variable': 'beta1', 'value': par[0]},], index=[0, 1, 2, 3])
    melt = pd.concat([melt, new_rows])
    print(melt)

    confusion_matrix = pd.crosstab(df['y'], df['y_pred'], rownames=['Actual'], colnames=['Predicted'])

    TN = confusion_matrix[0][0]
    TP = confusion_matrix[1][1]
    FN = confusion_matrix[0][1]
    FP = confusion_matrix[1][0]

    Sensitivity = TP/(TP + FN) 
    Specificity = TN/(TN + FP) 
    Accuracy = (TN + TP)/(TN+TP+FN+FP) 

    # Append rows in Empty Dataframe by adding dictionaries
    results3 = pd.concat([results3, 
                          pd.DataFrame([{'Sensitivity': Sensitivity, 'Specificity': Specificity, 'Accuracy': Accuracy}])], 
                          ignore_index=True)
    print(results3)
# Out:
# [-8.41526 -8.39208  1.92882 -8.51033  4.35375  4.35373 -8.50752 -8.5135
#  -8.47438 -8.49411]
# D_triu
# [[        nan 2.31804e-02 1.03441e+01 9.50659e-02 1.27690e+01 1.27690e+01
#   9.22615e-02 9.82424e-02 5.91151e-02 7.88462e-02]
#  [        nan         nan 1.03209e+01 1.18246e-01 1.27458e+01 1.27458e+01
#   1.15442e-01 1.21423e-01 8.22955e-02 1.02027e-01]
#  [        nan         nan         nan 1.04391e+01 2.42494e+00 2.42491e+00
#   1.04363e+01 1.04423e+01 1.04032e+01 1.04229e+01]
#  [        nan         nan         nan         nan 1.28641e+01 1.28641e+01
#   2.80440e-03 3.17648e-03 3.59508e-02 1.62197e-02]
#  [        nan         nan         nan         nan         nan 2.69609e-05
#   1.28613e+01 1.28673e+01 1.28281e+01 1.28479e+01]
#  [        nan         nan         nan         nan         nan         nan
#   1.28612e+01 1.28672e+01 1.28281e+01 1.28478e+01]
#  [        nan         nan         nan         nan         nan         nan
#           nan 5.98089e-03 3.31464e-02 1.34153e-02]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan 3.91273e-02 1.93961e-02]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan         nan 1.97311e-02]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan         nan         nan]]
# [-8.44711 -8.43301  1.92882 -8.50181  4.35373 -8.50031 -8.50358 -8.48172
#  -8.49281]
# D_triu
# [[        nan 1.40995e-02 1.03759e+01 5.47024e-02 1.28008e+01 5.31989e-02
#   5.64727e-02 3.46150e-02 4.57053e-02]
#  [        nan         nan 1.03618e+01 6.88019e-02 1.27867e+01 6.72984e-02
#   7.05722e-02 4.87145e-02 5.98048e-02]
#  [        nan         nan         nan 1.04306e+01 2.42491e+00 1.04291e+01
#   1.04324e+01 1.04105e+01 1.04216e+01]
#  [        nan         nan         nan         nan 1.28555e+01 1.50345e-03
#   1.77032e-03 2.00874e-02 8.99712e-03]
#  [        nan         nan         nan         nan         nan 1.28540e+01
#   1.28573e+01 1.28354e+01 1.28465e+01]
#  [        nan         nan         nan         nan         nan         nan
#   3.27378e-03 1.85839e-02 7.49367e-03]
#  [        nan         nan         nan         nan         nan         nan
#           nan 2.18577e-02 1.07674e-02]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan
+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan]]
# [  4.87782 -10.42057   2.04608   4.87785 -10.42053 -10.4186   -8.06269]
# D_triu
# [[        nan 1.52984e+01 2.83173e+00 2.92411e-05 1.52983e+01 1.52964e+01
#   1.29405e+01]
#  [        nan         nan 1.24666e+01 1.52984e+01 3.36052e-05 1.96356e-03
#   2.35787e+00]
#  [        nan         nan         nan 2.83176e+00 1.24666e+01 1.24647e+01
#   1.01088e+01]
#  [        nan         nan         nan         nan 1.52984e+01 1.52964e+01
#   1.29405e+01]
#  [        nan         nan         nan         nan         nan 1.92996e-03
#   2.35784e+00]
#  [        nan         nan         nan         nan         nan         nan
#   2.35591e+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan]]
# [  4.87803 -10.42012   2.04618 -10.42009 -10.41956  -8.06308]
# D_triu
# [[        nan 1.52981e+01 2.83184e+00 1.52981e+01 1.52976e+01 1.29411e+01]
#  [        nan         nan 1.24663e+01 3.36038e-05 5.64451e-04 2.35704e+00]
#  [        nan         nan         nan 1.24663e+01 1.24657e+01 1.01093e+01]
#  [        nan         nan         nan         nan 5.30847e-04 2.35700e+00]
#  [        nan         nan         nan         nan         nan 2.35647e+00]
#  [        nan         nan         nan         nan         nan         nan]]
# [  4.87803 -10.41987   2.04618 -10.41968  -8.06308]
# D_triu
# [[        nan 1.52979e+01 2.83184e+00 1.52977e+01 1.29411e+01]
#  [        nan         nan 1.24660e+01 1.82704e-04 2.35678e+00]
#  [        nan         nan         nan 1.24659e+01 1.01093e+01]
#  [        nan         nan         nan         nan 2.35660e+00]
#  [        nan         nan         nan         nan         nan]]
# [  4.87803 -10.41972   2.04618  -8.06308]
# D_triu
# [[     nan 15.29774  2.83184 12.94111]
#  [     nan      nan 12.4659   2.35663]
#  [     nan      nan      nan 10.10927]
#  [     nan      nan      nan      nan]]
# [ 4.7445  -9.57558  1.98772]
# D_triu
# [[     nan 14.32007  2.75678]
#  [     nan      nan 11.56329]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 14.32007      nan]
#  [     nan      nan 11.56329]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 14.32007      nan]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
# [ 4.73877 -9.56436  1.98519]
# D_triu
# [[     nan 14.30313  2.75357]
#  [     nan      nan 11.54955]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 14.30313      nan]
#  [     nan      nan 11.54955]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 14.30313      nan]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
# [ 4.73871 -9.5643   1.98519]
# D_triu
# [[     nan 14.30301  2.75352]
#  [     nan      nan 11.54949]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 14.30301      nan]
#  [     nan      nan 11.54949]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 14.30301      nan]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
# [ 4.73871 -9.5643   1.98519]
# D_triu
# [[     nan 14.30301  2.75352]
#  [     nan      nan 11.54949]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 14.30301      nan]
#  [     nan      nan 11.54949]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 14.30301      nan]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
# [ 4.73871 -9.5643   1.98519]
# D_triu
# [[     nan 14.30301  2.75352]
#  [     nan      nan 11.54949]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 14.30301      nan]
#  [     nan      nan 11.54949]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 14.30301      nan]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
#   variable     value
# 0     c1,1  4.353672
# 1     c1,2  1.928722
# 2     c1,3 -8.490711
# 3    beta1 -5.416867
# 0     c1,1  4.738710
# 1     c1,2  1.985193
# 2     c1,3 -9.564301
# 3    beta1 -5.865099
#    Sensitivity  Specificity  Accuracy
# 0     0.932367     0.918854  0.925570
# 1     0.950472     0.937799  0.944181
# [ 3.8637  -8.80291  3.86364 -8.80292  3.86364  3.82815  3.86365 -8.80291
+01]
#  [        nan         nan         nan         nan         nan         nan
#           nan]]
# [ 3.87361 -8.82075  3.87355  3.87357  3.87361  1.57863]
# D_triu
# [[        nan 1.26944e+01 5.95034e-05 4.19814e-05 1.46847e-06 2.29499e+00]
#  [        nan         nan 1.26943e+01 1.26943e+01 1.26944e+01 1.03994e+01]
#  [        nan         nan         nan 1.75220e-05 5.80349e-05 2.29493e+00]
#  [        nan         nan         nan         nan 4.05129e-05 2.29494e+00]
#  [        nan         nan         nan         nan         nan 2.29498e+00]
#  [        nan         nan         nan         nan         nan         nan]]
# [ 3.87361 -8.82075  3.87355  3.87357  1.57863]
# D_triu
# [[        nan 1.26944e+01 5.80349e-05 4.05129e-05 2.29498e+00]
#  [        nan         nan 1.26943e+01 1.26943e+01 1.03994e+01]
#  [        nan         nan         nan 1.75220e-05 2.29493e+00]
#  [        nan         nan         nan         nan 2.29494e+00]
#  [        nan         nan         nan         nan         nan]]
# [ 3.87361 -8.82075  3.87355  1.57863]
# D_triu
# [[        nan 1.26944e+01 5.78549e-05 2.29498e+00]
#  [        nan         nan 1.26943e+01 1.03994e+01]
#  [        nan         nan         nan 2.29493e+00]
#  [        nan         nan         nan         nan]]
# [ 3.8736  -8.82075  1.57863]
# D_triu
# [[     nan 12.69435  2.29497]
#  [     nan      nan 10.39938]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 12.69435      nan]
#  [     nan      nan 10.39938]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 12.69435      nan]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
# [ 3.8736  -8.82075  1.57863]
# D_triu
# [[     nan 12.69435  2.29497]
#  [     nan      nan 10.39938]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 12.69435      nan]
#  [     nan      nan 10.39938]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 12.69435      nan]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
#   variable     value
# 0     c1,1  4.353672
# 1     c1,2  1.928722
# 2     c1,3 -8.490711
# 3    beta1 -5.416867
# 0     c1,1  4.738710
# 1     c1,2  1.985193
# 2     c1,3 -9.564301
# 3    beta1 -5.865099
# 0     c1,1  3.873597
# 1     c1,2  1.578626
# 2     c1,3 -8.820753
# 3    beta1 -5.537847
#    Sensitivity  Specificity  Accuracy
# 0     0.932367     0.918854  0.925570
# 1     0.950472     0.937799  0.944181
# 2     0.934579     0.954762  0.944575
# [  4.73121   2.17017 -10.66931 -10.66932   4.73121 -10.66934   2.1703
#  -10.6693    2.17018 -10.66934]
# D_triu
# [[        nan 2.56104e+00 1.54005e+01 1.54005e+01 2.62864e-07 1.54006e+01
#   2.56091e+00 1.54005e+01 2.56103e+00 1.54005e+01]
#  [        nan         nan 1.28395e+01 1.28395e+01 2.56104e+00 1.28395e+01
#   1.32334e-04 1.28395e+01 5.68703e-06 1.28395e+01]
#  [        nan         nan         nan 7.62687e-06 1.54005e+01 2.83741e-05
#   1.28396e+01 1.52500e-05 1.28395e+01 2.43875e-05]
#  [        nan         nan         nan         nan 1.54005e+01 2.07472e-05
#   1.28396e+01 2.28769e-05 1.28395e+01 1.67606e-05]
#  [        nan         nan         nan         nan         nan 1.54006e+01
#   2.56091e+00 1.54005e+01 2.56103e+00 1.54005e+01]
#  [        nan         nan         nan         nan         nan         nan
#   1.28396e+01 4.36241e-05 1.28395e+01 3.98665e-06]
#  [        nan         nan         nan         nan         nan         nan
#           nan 1
# D_triu
# [[        nan 2.56088e+00 1.54005e+01 1.54005e+01 2.56091e+00]
#  [        nan         nan 1.28396e+01 1.28397e+01 2.66164e-05]
#  [        nan         nan         nan 2.43086e-05 1.28396e+01]
#  [        nan         nan         nan         nan 1.28396e+01]
#  [        nan         nan         nan         nan         nan]]
# [  4.73121   2.17033 -10.66932   2.1703 ]
# D_triu
# [[        nan 2.56088e+00 1.54005e+01 2.56091e+00]
#  [        nan         nan 1.28396e+01 2.66164e-05]
#  [        nan         nan         nan 1.28396e+01]
#  [        nan         nan         nan         nan]]
# [  4.73121   2.1703  -10.66932]
# D_triu
# [[     nan  2.56091 15.40052]
#  [     nan      nan 12.83962]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 15.40052]
#  [     nan      nan 12.83962]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 15.40052]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
# [  4.73121   2.1703  -10.66932]
# D_triu
# [[     nan  2.56091 15.40052]
#  [     nan      nan 12.83962]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 15.40052]
#  [     nan      nan 12.83962]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 15.40052]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
#   variable      value
# 0     c1,1   4.353672
# 1     c1,2   1.928722
# 2     c1,3  -8.490711
# 3    beta1  -5.416867
# 0     c1,1   4.738710
# 1     c1,2   1.985193
# 2     c1,3  -9.564301
# 3    beta1  -5.865099
# 0     c1,1   3.873597
# 1     c1,2   1.578626
# 2     c1,3  -8.820753
# 3    beta1  -5.537847
# 0     c1,1   4.731209
# 1     c1,2   2.170302
# 2     c1,3 -10.669315
# 3    beta1  -6.630355
#    Sensitivity  Specificity  Accuracy
# 0     0.932367     0.918854  0.925570
# 1     0.950472     0.937799  0.944181
# 2     0.934579     0.954762  0.944575
# 3     0.921951     0.947991  0.935174
# [-8.17419  4.1671   1.89265 -8.65026  4.16707 -8.57919  4.16709  4.16709
#  -8.4617   4.1671 ]
# D_triu
# [[        nan 1.23413e+01 1.00668e+01 4.76073e-01 1.23413e+01 4.05008e-01
#   1.23413e+01 1.23413e+01 2.87510e-01 1.23413e+01]
#  [        nan         nan 2.27445e+00 1.28174e+01 2.45002e-05 1.27463e+01
#   1.03292e-05 6.34732e-06 1.26288e+01 5.35089e-06]
#  [        nan         nan         nan 1.05429e+01 2.27442e+00 1.04718e+01
#   2.27444e+00 2.27444e+00 1.03544e+01 2.27445e+00]
#  [        nan         nan         nan         nan 1.28173e+01 7.10651e-02
#   1.28173e+01 1.28174e+01 1.88562e-01 1.28174e+01]
#  [        nan         nan         nan         nan         nan 1.27463e+01
#   1.41710e-05 1.81529e-05 1.26288e+01 2.98511e-05]
#  [        nan         nan         nan         nan         nan         nan
#   1.27463e+01 1.27463e+01 1.17497e-01 1.27463e+01]
#  [        nan         nan         nan         nan         nan         nan
#           nan 3.98184e-06 1.26288e+01 1.56801e-05]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan 1.26288e+01 1.16982e-05]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan         nan 1.26288e+01]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan         nan         nan]]
# [-8.22428  4.1671   1.89265 -8.62101  4.16707 -8.56495  4.16709 -8.468
#   4.1671 ]
# D_triu
# [[        nan 1.23914e+01 1.01169e+01 3.96732e-01 1.23914e+01 3.40674e-01
#   1.23914e+01 2.43720e-01 1.23914e+01]
#  [        nan         nan 2.27445e+00 1.27881e+01 2.45002e-05 1.27321e+01
#   6.34733e-06 1.26351e+01 5.35089e-06]
#  [        nan         nan         nan 1.05137e+01 2.27442e+00 1.04576e+01
#   2.27444e+00 1.03607e+01 2.27445e+00]
#  [        nan         nan         nan         nan 1.27881e+01 5.60583e-02
#   1.27881e+01 1.53012e-01 1.27881e+01]
#  [        nan         nan         nan         nan         nan 1.27320e+01
#   1.81528e-05 1.26351e+01 2.98511e-05]
#  [        nan         nan         nan         nan         nan         nan
#   1.27320e+01 9.69536e-02 1.27321e+01]
#  [        nan         nan         nan         nan         nan         nan
#           nan 1.26351e+01 1.16982e-05]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan 1.26351e+01]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan         nan]]
# [-8.26584  4.1671   1.89265 -8.59812  4.16707 -8.55335  4.16709 -8.47317]
# D_triu
# [[        nan 1.24329e+01 1.01585e+01 3.32280e-01 1.24329e+01 2.87506e-01
#   1.24329e+01 2.07326e-01]
#  [        nan         nan 2.27445e+00 1.27652e+01 2.98045e-05 1.27205e+01
#   1.16517e-05 1.26403e+01]
#  [        nan         nan         nan 1.04908e+01 2.27442e+00 1.04460e+01
#   2.27444e+00 1.03658e+01]
#  [        nan         nan         nan         nan 1.27652e+01 4.47746e-02
#   1.27652e+01 1.24954e-01]
#  [        nan         nan         nan         nan         nan 1.27204e+01
#   1.81528e-05 1.26402e+01]
#  [        nan         nan         nan         nan         nan         nan
#   1.27204e+01 8.01798e-02]
#  [        nan         nan         nan         nan         nan         nan
#           nan 1.26403e+01]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan]]
# [-8.30085  4.1671   1.89265 -8.57996  4.16707 -8.54385 -8.47741]
# D_triu
# [[        nan 1.24680e+01 1.01935e+01 2.79110e-01 1.24679e+01 2.42991e-01
#   1.76554e-01]
#  [        nan         nan 2.27445e+00 1.27471e+01 2.80886e-05 1.27109e+01
#   1.26445e+01]
#  [        nan         nan         nan 1.04726e+01 2.27442e+00 1.04365e+01
#   1.03701e+01]
#  [        nan         nan         nan         nan 1.27470e+01 3.61184e-02
#   1.02556e-01]
#  [        nan         nan         nan         nan         nan 1.27109e+01
#   1.26445e+01]
#  [        nan         nan         nan         nan         nan         nan
#   6.64376e-02]
#  [        nan         nan         nan         nan         nan         nan
#           nan]]
# [-8.33064  4.16713  1.89265 -8.56546 -8.53613 -8.48103]
# D_triu
# [[     nan 12.49777 10.2233   0.23481  0.20548  0.15038]
#  [     nan      nan  2.27447 12.73258 12.70325 12.64816]
#  [     nan      nan      nan 10.45811 10.42878 10.37368]
#  [     nan      nan      nan      nan  0.02933  0.08443]
#  [     nan      nan      nan      nan      nan  0.0551 ]
#  [     nan      nan      nan      nan      nan      nan]]
# [-8.35597  4.16713  1.89265 -8.52967 -8.48393]
# D_triu
# [[     nan 12.52309 10.24862  0.1737   0.12796]
#  [     nan      nan  2.27447 12.69679 12.65105]
#  [     nan      nan      nan 10.42232 10.37658]
#  [     nan      nan      nan      nan  0.04574]
#  [     nan      nan      nan      nan      nan]]
# [-8.37749  4.16713  1.89265 -8.49815]
# D_triu
# [[     nan 12.54461 10.27014  0.12066]
#  [     nan      nan  2.27447 12.66528]
#  [     nan      nan      nan 10.3908 ]
#  [     nan      nan      nan      nan]]
# [-8.49815  4.16713  1.89265]
# D_triu
# [[     nan 12.66528 10.3908 ]
#  [     nan      nan  2.27447]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan
+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan 1.83588e+01]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan]]
# [  6.10622   2.56008   2.5607  -12.396     2.56002 -12.28533   6.08686]
# D_triu
# [[        nan 3.54614e+00 3.54552e+00 1.85022e+01 3.54620e+00 1.83915e+01
#   1.93621e-02]
#  [        nan         nan 6.19497e-04 1.49561e+01 5.75368e-05 1.48454e+01
#   3.52678e+00]
#  [        nan         nan         nan 1.49567e+01 6.77034e-04 1.48460e+01
#   3.52616e+00]
#  [        nan         nan         nan         nan 1.49560e+01 1.10666e-01
#   1.84829e+01]
#  [        nan         nan         nan         nan         nan 1.48454e+01
#   3.52684e+00]
#  [        nan         nan         nan         nan         nan         nan
#   1.83722e+01]
#  [        nan         nan         nan         nan         nan         nan
#           nan]]
# [  6.10026   2.56006   2.56039 -12.396   -12.29688   6.08693]
# D_triu
# [[        nan 3.54020e+00 3.53987e+00 1.84963e+01 1.83971e+01 1.33247e-02]
#  [        nan         nan 3.30923e-04 1.49561e+01 1.48569e+01 3.52688e+00]
#  [        nan         nan         nan 1.49564e+01 1.48573e+01 3.52655e+00]
#  [        nan         nan         nan         nan 9.91187e-02 1.84829e+01]
#  [        nan         nan         nan         nan         nan 1.83838e+01]
#  [        nan         nan         nan         nan         nan         nan]]
# [  6.09616   2.56006 -12.396   -12.30694   6.08693]
# D_triu
# [[        nan 3.53611e+00 1.84922e+01 1.84031e+01 9.22903e-03]
#  [        nan         nan 1.49561e+01 1.48670e+01 3.52688e+00]
#  [        nan         nan         nan 8.90614e-02 1.84829e+01]
#  [        nan         nan         nan         nan 1.83939e+01]
#  [        nan         nan         nan         nan         nan]]
# [  6.08704   2.56006 -12.396   -12.3158 ]
# D_triu
# [[     nan  3.52698 18.48303 18.40283]
#  [     nan      nan 14.95605 14.87585]
#  [     nan      nan      nan  0.0802 ]
#  [     nan      nan      nan      nan]]
# [  6.08704   2.56006 -12.39596]
# D_triu
# [[     nan  3.52698 18.483  ]
#  [     nan      nan 14.95602]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 18.483  ]
#  [     nan      nan 14.95602]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[   nan    nan 18.483]
#  [   nan    nan    nan]
#  [   nan    nan    nan]]
# I move on to the check other masses
# [  6.08704   2.56006 -12.39596]
# D_triu
# [[     nan  3.52698 18.483  ]
#  [     nan      nan 14.95602]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 18.483  ]
#  [     nan      nan 14.95602]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[   nan    nan 18.483]
#  [   nan    nan    nan]
#  [   nan    nan    nan]]
# I move on to the check other masses
#   variable      value
# 0     c1,1   4.353672
# 1     c1,2   1.928722
# 2     c1,3  -8.490711
# 3    beta1  -5.416867
# 0     c1,1   4.738710
# 1     c1,2   1.985193
# 2     c1,3  -9.564301
# 3    beta1  -5.865099
# 0     c1,1   3.873597
# 1     c1,2   1.578626
# 2     c1,3  -8.820753
# 3    beta1  -5.537847
# 0     c1,1   4.731209
# 1     c1,2   2.170302
# 2     c1,3 -10.669315
# 3    beta1  -6.630355
# 0     c1,1   4.167126
# 1     c1,2   1.892653
# 2     c1,3  -8.498150
# 3    beta1  -5.469124
# 0     c1,1   5.503586
# 1     c1,2   1.869427
# 2     c1,3 -10.250597
# 3    beta1  -6.599496
# 0     c1,1   6.087036
# 1     c1,2   2.560055
# 2     c1,3 -12.395964
# 3    beta1  -7.544334
#    Sensitivity  Specificity  Accuracy
# 0     0.932367     0.918854  0.925570
# 1     0.950472     0.937799  0.944181
# 2     0.934579     0.954762  0.944575
# 3     0.921951     0.947991  0.935174
# 4     0.918919     0.935345  0.927313
# 5     0.915119     0.944976  0.930818
# 6     0.939759     0.964103  0.951553
# [  5.77423 -11.58891 -11.58948   5.76823 -11.59082   2.65681   2.65681
#    5.7742  -11.59101   5.77423]
# D_triu
# [[        nan 1.73631e+01 1.73637e+01 5.99853e-03 1.73651e+01 3.11742e+00
#   3.11742e+00 2.98820e-05 1.73652e+01 1.88469e-06]
#  [        nan         nan 5.66151e-04 1.73571e+01 1.91242e-03 1.42457e+01
#   1.42457e+01 1.73631e+01 2.10222e-03 1.73631e+01]
#  [        nan         nan         nan 1.73577e+01 1.34627e-03 1.42463e+01
#   1.42463e+01 1.73637e+01 1.53607e-03 1.73637e+01]
#  [        nan         nan         nan         nan 1.73591e+01 3.11143e+00
#   3.11142e+00 5.96865e-03 1.73592e+01 6.00042e-03]
#  [        nan         nan         nan         nan         nan 1.42476e+01
# ...
#  [        nan         nan         nan         nan         nan         nan]]
# [ 4.5087   2.0981   2.09826 -9.58735 -9.58615]
# D_triu
# [[        nan 2.41060e+00 2.41044e+00 1.40960e+01 1.40948e+01]
#  [        nan         nan 1.63483e-04 1.16854e+01 1.16842e+01]
#  [        nan         nan         nan 1.16856e+01 1.16844e+01]
#  [        nan         nan         nan         nan 1.20782e-03]
#  [        nan         nan         nan         nan         nan]]
# [ 4.5087   2.09813 -9.58706 -9.5862 ]
# D_triu
# [[        nan 2.41057e+00 1.40958e+01 1.40949e+01]
#  [        nan         nan 1.16852e+01 1.16843e+01]
#  [        nan         nan         nan 8.56730e-04]
#  [        nan         nan         nan         nan]]
# [ 4.5087   2.09813 -9.58643]
# D_triu
# [[     nan  2.41057 14.09513]
#  [     nan      nan 11.68456]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 14.09513]
#  [     nan      nan 11.68456]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 14.09513]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
# [ 4.5087   2.09813 -9.58643]
# D_triu
# [[     nan  2.41057 14.09513]
#  [     nan      nan 11.68456]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 14.09513]
#  [     nan      nan 11.68456]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 14.09513]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
#    variable     value
# 0      c1,1  4.353672
# 1      c1,2  1.928722
# 2      c1,3 -8.490711
# 3     beta1 -5.416867
# 0      c1,1  4.738710
# ..      ...       ...
# 3     beta1 -7.098865
# 0      c1,1  4.508697
# 1      c1,2  2.098126
# 2      c1,3 -9.586433
# 3     beta1 -6.059125
#
# [392 rows x 2 columns]
#     Sensitivity  Specificity  Accuracy
# 0      0.932367     0.918854  0.925570
# 1      0.950472     0.937799  0.944181
# 2      0.934579     0.954762  0.944575
# 3      0.921951     0.947991  0.935174
# 4      0.918919     0.935345  0.927313
# ..          ...          ...       ...
# 93     0.919240     0.948403  0.933575
# 94     0.948020     0.907543  0.927607
+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan]]
# [-9.45695 -9.45693 -9.45694  4.35502  4.35498  2.22684  4.35499]
# D_triu
# [[        nan 1.46724e-05 9.48489e-06 1.38120e+01 1.38119e+01 1.16838e+01
#   1.38119e+01]
#  [        nan         nan 5.18748e-06 1.38120e+01 1.38119e+01 1.16838e+01
#   1.38119e+01]
#  [        nan         nan         nan 1.38120e+01 1.38119e+01 1.16838e+01
#   1.38119e+01]
#  [        nan         nan         nan         nan 4.05374e-05 2.12819e+00
#   3.20684e-05]
#  [        nan         nan         nan         nan         nan 2.12814e+00
#   8.46903e-06]
#  [        nan         nan         nan         nan         nan         nan
#   2.12815e+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan]]
# [-9.45695 -9.45694  4.35502  4.35498  2.22684  4.35499]
# D_triu
# [[        nan 1.02199e-05 1.38120e+01 1.38119e+01 1.16838e+01 1.38119e+01]
#  [        nan         nan 1.38120e+01 1.38119e+01 1.16838e+01 1.38119e+01]
#  [        nan         nan         nan 4.05374e-05 2.12819e+00 3.20684e-05]
#  [        nan         nan         nan         nan 2.12814e+00 8.46903e-06]
#  [        nan         nan         nan         nan         nan 2.12815e+00]
#  [        nan         nan         nan         nan         nan         nan]]
# [-9.45695 -9.45694  4.35502  4.35499  2.22684]
# D_triu
# [[        nan 1.02199e-05 1.38120e+01 1.38119e+01 1.16838e+01]
#  [        nan         nan 1.38120e+01 1.38119e+01 1.16838e+01]
#  [        nan         nan         nan 3.20684e-05 2.12819e+00]
#  [        nan         nan         nan         nan 2.12815e+00]
#  [        nan         nan         nan         nan         nan]]
# [-9.45694  4.35502  4.35499  2.22684]
# D_triu
# [[        nan 1.38120e+01 1.38119e+01 1.16838e+01]
#  [        nan         nan 3.20684e-05 2.12819e+00]
#  [        nan         nan         nan 2.12815e+00]
#  [        nan         nan         nan         nan]]
# [-9.45694  4.35502  2.22684]
# D_triu
# [[     nan 13.81196 11.68378]
#  [     nan      nan  2.12818]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 13.81196 11.68378]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 13.81196      nan]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
# [-9.45694  4.35502  2.22684]
# D_triu
# [[     nan 13.81196 11.68378]
#  [     nan      nan  2.12818]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 13.81196 11.68378]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan 13.81196      nan]
#  [     nan      nan      nan]
#  [     nan      nan      nan]]
# I move on to the check other masses
#    variable     value
# 0      c1,1  4.353672
# 1      c1,2  1.928722
# 2      c1,3 -8.490711
# 3     beta1 -5.416867
# 0      c1,1  4.738710
# ..      ...       ...
# 3     beta1 -6.059125
# 0      c1,1  4.355021
# 1      c1,2  2.226838
# 2      c1,3 -9.456940
# 3     beta1 -5.932238
#
# [396 rows x 2 columns]
#     Sensitivity  Specificity  Accuracy
# 0      0.932367     0.918854  0.925570
# 1      0.950472     0.937799  0.944181
# 2      0.934579     0.954762  0.944575
# 3      0.921951     0.947991  0.935174
# 4      0.918919     0.935345  0.927313
# ..          ...          ...       ...
# 94     0.948020     0.907543  0.927607
# 95     0.956757     0.931818  0.943210
# 96     0.917989     0.912854  0.915173
# 97     0.936740     0.948081  0.942623
# 98     0.939252     0.933180  0.936195
#
# [99 rows x 3 columns]
# [ 2.20391  4.77039 -9.72631 -9.75212 -9.75559 -9.7288   2.20374  4.77101
#  -9.71008  4.76869]
# D_triu
# [[        nan 2.56647e+00 1.19302e+01 1.19560e+01 1.19595e+01 1.19327e+01
#  [        nan         nan         nan         nan         nan         nan
#   3.60765e-03]
#  [        nan         nan         nan         nan         nan         nan
#           nan]]
# [ 2.20388  4.76889 -9.73434 -9.73695 -9.73732 -9.73238]
# D_triu
# [[        nan 2.56501e+00 1.19382e+01 1.19408e+01 1.19412e+01 1.19363e+01]
#  [        nan         nan 1.45032e+01 1.45058e+01 1.45062e+01 1.45013e+01]
#  [        nan         nan         nan 2.60797e-03 2.97895e-03 1.95546e-03]
#  [        nan         nan         nan         nan 3.70980e-04 4.56344e-03]
#  [        nan         nan         nan         nan         nan 4.93442e-03]
#  [        nan         nan         nan         nan         nan         nan]]
# [ 2.20388  4.76889 -9.73469 -9.7362  -9.73357]
# D_triu
# [[        nan 2.56501e+00 1.19386e+01 1.19401e+01 1.19375e+01]
#  [        nan         nan 1.45036e+01 1.45051e+01 1.45025e+01]
#  [        nan         nan         nan 1.50698e-03 1.12391e-03]
#  [        nan         nan         nan         nan 2.63089e-03]
#  [        nan         nan         nan         nan         nan]]
# [ 2.20388  4.76889 -9.73487 -9.73573]
# D_triu
# [[        nan 2.56501e+00 1.19388e+01 1.19396e+01]
#  [        nan         nan 1.45038e+01 1.45046e+01]
#  [        nan         nan         nan 8.53353e-04]
#  [        nan         nan         nan         nan]]
# [ 2.20388  4.76889 -9.73513]
# D_triu
# [[     nan  2.56501 11.93901]
#  [     nan      nan 14.50402]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 11.93901]
#  [     nan      nan 14.50402]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan      nan]
#  [     nan      nan 14.50402]
#  [     nan      nan      nan]]
# I move on to the check other masses
# [ 2.20388  4.76889 -9.73513]
# D_triu
# [[     nan  2.56501 11.93901]
#  [     nan      nan 14.50402]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan 11.93901]
#  [     nan      nan 14.50402]
#  [     nan      nan      nan]]
# I move on to the check other masses
# D_triu
# [[     nan      nan      nan]
#  [     nan      nan 14.50402]
#  [     nan      nan      nan]]
# I move on to the check other masses
#    variable     value
# 0      c1,1  4.353672
# 1      c1,2  1.928722
# 2      c1,3 -8.490711
# 3     beta1 -5.416867
# 0      c1,1  4.738710
# ..      ...       ...
# 3     beta1 -5.932238
# 0      c1,1  4.768889
# 1      c1,2  2.203883
# 2      c1,3 -9.735131
# 3     beta1 -5.787887
#
# [400 rows x 2 columns]
#     Sensitivity  Specificity  Accuracy
# 0      0.932367     0.918854  0.925570
# 1      0.950472     0.937799  0.944181
# 2      0.934579     0.954762  0.944575
# 3      0.921951     0.947991  0.935174
# 4      0.918919     0.935345  0.927313
# ..          ...          ...       ...
# 95     0.956757     0.931818  0.943210
# 96     0.917989     0.912854  0.915173
# 97     0.936740     0.948081  0.942623
# 98     0.939252     0.933180  0.936195
# 99     0.949153     0.932668  0.941032
#
# [100 rows x 3 columns]

# %%
filename = 'results3' + '.csv'
results3.to_csv('output/comparison_state_of_art/Bernoulli_GLMMDRE_output/' + filename)

filename = 'melt' +'.csv'
melt.to_csv('output/comparison_state_of_art/Bernoulli_GLMMDRE_output/' + filename)

# %% [markdown]
# ## Poisson

# %%
# POISSON
results3_POI = pd.DataFrame(columns=['MSE', 'MSE_log', 'Chi-Squared-Error'])
melt_POI = pd.DataFrame(columns=['variable', 'value'])

for file in os.listdir('output/comparison_state_of_art/Poisson_DG_output/'):
  if file.endswith(".csv"):
    cond = True
    while cond:
        try:
            df = pd.read_csv('output/comparison_state_of_art/Poisson_DG_output/' + file).iloc[:,1:]

            N = df.g.nunique()
            lengths = np.array(df.groupby('g').count().reset_index().iloc[:,1])
            y = list(df.groupby('g')['y'].apply(np.array).values)

            fix = defaultdict(list)

            fix[0] = df.groupby('g')['x1'].apply(np.array).values.tolist()

            ran_var = False
            ran_int = True
            n_fix = 1
            tol = 0.05
            sim = True

            knots, par, W, hess_ran, hess_fix, modeleval = algorithm_alpha(ran_var, ran_int, n_fix, sim, tol, model = 'P', 
                                                                fix=None, lengths=None, y=None, N=None, t=None)

            x = compute_order(knots)
            knots = knots[x]
            W = W[:, x]

            group = np.array([np.nan if np.sum(W[i,:])==0 else np.argmax(W[i,:]) for i in range(N)])

            if len(knots)==3:
              cond = False
        except:
            pass    
    
    df['ran_int'] = df['g'].apply(lambda x: knots[0] if x == 1 or x == 2 else knots[2] if x == 8 or x == 9 or x == 10 else knots[1])

    temp = par * df['x1'] + df['ran_int']
    df['y_pred'] = temp.apply(lambda x: round(np.exp(x)))

    # Append rows in Empty Dataframe by adding dictionaries
    new_rows = pd.DataFrame([
    {'variable': 'c1,1', 'value': knots[0]},
    {'variable': 'c1,2', 'value': knots[1]},
    {'variable': 'c1,3', 'value': knots[2]},
    {'variable': 'beta1', 'value': par[0]},], index=[0, 1, 2, 3])
    melt_POI = pd.concat([melt_POI, new_rows])
    print(melt_POI)

    MSE = np.mean((df['y'] - df['y_pred'])**2)
    MSE_log = np.mean((np.log(df['y']+1) - np.log(df['y_pred']+1))**2)
    CSE = np.mean((df['y'] - df['y_pred'])**2 / (df['y_pred']+1))


    # Append rows in Empty Dataframe by adding dictionaries
    results3_POI = pd.concat([results3_POI, pd.DataFrame([{'MSE': MSE, 'MSE_log': MSE_log, 'Chi-Squared-Error': CSE}])], ignore_index=True)
    print(results3_POI)
# Out:
# [ 2.49338 -0.9913  -0.99061  1.04451  0.99651 -0.99115  1.04377 -0.99137
#   2.49337  2.49336]
# D_triu
# [[        nan 3.48468e+00 3.48398e+00 1.44886e+00 1.49687e+00 3.48452e+00
#   1.44961e+00 3.48474e+00 2.52959e-06 1.71087e-05]
#  [        nan         nan 6.93717e-04 2.03581e+00 1.98781e+00 1.51714e-04
#   2.03507e+00 6.71199e-05 3.48467e+00 3.48466e+00]
#  [        nan         nan         nan 2.03512e+00 1.98711e+00 5.42003e-04
#   2.03437e+00 7.60837e-04 3.48398e+00 3.48396e+00]
#  [        nan         nan         nan         nan 4.80057e-02 2.03566e+00
#   7.42674e-04 2.03588e+00 1.44886e+00 1.44885e+00]
#  [        nan         nan         nan         nan         nan 1.98765e+00
#   4.72630e-02 1.98787e+00 1.49687e+00 1.49685e+00]
#  [        nan         nan         nan         nan         nan         nan
#   2.03492e+00 2.18834e-04 3.48452e+00 3.48451e+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan 2.03514e+00 1.44960e+00 1.44959e+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan
#  [        nan         nan 2.02809e+00 1.99537e+00 2.02791e+00]
#  [        nan         nan         nan 3.27203e-02 1.79817e-04]
#  [        nan         nan         nan         nan 3.25405e-02]
#  [        nan         nan         nan         nan         nan]]
# [ 2.49337 -0.99105  1.03595  1.00539]
# D_triu
# [[    nan 3.48442 1.45743 1.48798]
#  [    nan     nan 2.027   1.99645]
#  [    nan     nan     nan 0.03055]
#  [    nan     nan     nan     nan]]
# [ 2.49343 -0.99105  1.02255]
# D_triu
# [[    nan 3.48449 1.47089]
#  [    nan     nan 2.0136 ]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 3.48449     nan]
#  [    nan     nan 2.0136 ]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 3.48449     nan]
#  [    nan     nan     nan]
#  [    nan     nan     nan]]
# I move on to the check other masses
# [ 2.49343 -0.99105  1.02255]
# D_triu
# [[    nan 3.48449 1.47089]
#  [    nan     nan 2.0136 ]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 3.48449     nan]
#  [    nan     nan 2.0136 ]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 3.48449     nan]
#  [    nan     nan     nan]
#  [    nan     nan     nan]]
# I move on to the check other masses
# [ 2.49343 -0.99105  1.02255]
# D_triu
# [[    nan 3.48449 1.47089]
#  [    nan     nan 2.0136 ]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 3.48449     nan]
#  [    nan     nan 2.0136 ]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 3.48449     nan]
#  [    nan     nan     nan]
#  [    nan     nan     nan]]
# I move on to the check other masses
#   variable     value
# 0     c1,1  2.493435
# 1     c1,2  1.022547
# 2     c1,3 -0.991051
# 3    beta1  0.281123
#         MSE   MSE_log  Chi-Squared-Error
# 0  3.871158  0.183004           0.621896
# [ 0.93884 -0.63504 -0.63505  0.93882 -0.63509  0.93879 -0.63506  2.50327
#  -1.19724  0.93874]
# D_triu
# [[        nan 1.57388e+00 1.57389e+00 2.08256e-05 1.57392e+00 4.83123e-05
#   1.57390e+00 1.56444e+00 2.13608e+00 9.30885e-05]
#  [        nan         nan 1.31411e-05 1.57385e+00 4.65920e-05 1.57383e+00
#   2.05204e-05 3.13831e+00 5.62204e-01 1.57378e+00]
#  [        nan         nan         nan 1.57387e+00 3.34509e-05 1.57384e+00
#   7.37927e-06 3.13833e+00 5.62191e-01 1.57380e+00]
#  [        nan         nan         nan         nan 1.57390e+00 2.74867e-05
#   1.57387e+00 1.56446e+00 2.13606e+00 7.22629e-05]
#  [        nan         nan         nan         nan         nan 1.57387e+00
#   2.60716e-05 3.13836e+00 5.62158e-01 1.57383e+00]
#  [        nan         nan         nan         nan         nan         nan
#   1.57385e+00 1.56449e+00 2.13603e+00 4.47762e-05]
#  [        nan         nan         nan         nan         nan         nan
#           nan 3.13833e+00 5.62184e-01 1.57380e+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan 3.70052e+00 1.56453e+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan         nan 2.13599e+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan         nan         nan]]
# [ 0.93884 -0.63504 -0.63505  0.93882 -0.63509  0.93879  2.50327 -1.19724
#   0.93874]
# D_triu
# [[        nan 1.57388e+00 1.57389e+00 2.08256e-05 1.57392e+00 4.83123e-05
#   1.56444e+00 2.13608e+00 9.30885e-05]
#  [        nan         nan 1.55407e-05 1.57385e+00 4.65920e-05 1.57383e+00
#   3.13831e+00 5.62204e-01 1.57378e+00]
#  [        nan         nan         nan 1.57387e+00 3.10512e-05 1.57384e+00

#  [        nan         nan         nan         nan         nan         nan
#           nan         nan         nan]]
# [ 1.05751 -1.10762 -1.10764 -1.10763  1.05748  2.47695  2.4737   2.46887]
# D_triu
# [[        nan 2.16512e+00 2.16515e+00 2.16514e+00 2.66980e-05 1.41945e+00
#   1.41619e+00 1.41136e+00]
#  [        nan         nan 2.69697e-05 1.17625e-05 2.16510e+00 3.58457e+00
#   3.58132e+00 3.57649e+00]
#  [        nan         nan         nan 1.52072e-05 2.16512e+00 3.58460e+00
#   3.58135e+00 3.57651e+00]
#  [        nan         nan         nan         nan 2.16511e+00 3.58458e+00
#   3.58133e+00 3.57650e+00]
#  [        nan         nan         nan         nan         nan 1.41947e+00
#   1.41622e+00 1.41139e+00]
#  [        nan         nan         nan         nan         nan         nan
#   3.25093e-03 8.08360e-03]
#  [        nan         nan         nan         nan         nan         nan
#           nan 4.83268e-03]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan]]
# [ 1.05751 -1.10762 -1.10764  1.05748  2.47623  2.4737   2.46995]
# D_triu
# [[        nan 2.16512e+00 2.16515e+00 2.66980e-05 1.41872e+00 1.41619e+00
#   1.41245e+00]
#  [        nan         nan 2.69015e-05 2.16510e+00 3.58384e+00 3.58132e+00
#   3.57757e+00]
#  [        nan         nan         nan 2.16512e+00 3.58387e+00 3.58135e+00
#   3.57760e+00]
#  [        nan         nan         nan         nan 1.41875e+00 1.41622e+00
#   1.41247e+00]
#  [        nan         nan         nan         nan         nan 2.52526e-03
#   6.27298e-03]
#  [        nan         nan         nan         nan         nan         nan
#   3.74772e-03]
#  [        nan         nan         nan         nan         nan         nan
#           nan]]
# [ 1.05749 -1.10762 -1.10764  2.47562  2.4737   2.4708 ]
# D_triu
# [[        nan 2.16511e+00 2.16514e+00 1.41813e+00 1.41621e+00 1.41330e+00]
#  [        nan         nan 2.69015e-05 3.58324e+00 3.58132e+00 3.57842e+00]
#  [        nan         nan         nan 3.58327e+00 3.58135e+00 3.57844e+00]
#  [        nan         nan         nan         nan 1.92071e-03 4.82421e-03]
#  [        nan         nan         nan         nan         nan 2.90350e-03]
#  [        nan         nan         nan         nan         nan         nan]]
# [ 1.05749 -1.10762  2.4752   2.4737   2.47146]
# D_triu
# [[        nan 2.16511e+00 1.41771e+00 1.41621e+00 1.41397e+00]
#  [        nan         nan 3.58282e+00 3.58132e+00 3.57908e+00]
#  [        nan         nan         nan 1.49763e-03 3.73759e-03]
#  [        nan         nan         nan         nan 2.23996e-03]
#  [        nan         nan         nan         nan         nan]]
# [ 1.05749 -1.10762  2.4737   2.47195]
# D_triu
# [[        nan 2.16511e+00 1.41621e+00 1.41445e+00]
#  [        nan         nan 3.58132e+00 3.57956e+00]
#  [        nan         nan         nan 1.75725e-03]
#  [        nan         nan         nan         nan]]
# [ 1.05749 -1.10762  2.4737 ]
# D_triu
# [[    nan 2.16511 1.41621]
#  [    nan     nan 3.58132]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 2.16511     nan]
#  [    nan     nan 3.58132]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan     nan     nan]
#  [    nan     nan 3.58132]
#  [    nan     nan     nan]]
# I move on to the check other masses
# [ 1.05749 -1.10762  2.4737 ]
# D_triu
# [[    nan 2.16511 1.41621]
#  [    nan     nan 3.58132]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 2.16511     nan]
#  [    nan     nan 3.58132]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    n
+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan         nan]]
# [ 0.9902  -1.03193  0.99318 -1.02222  2.48651  0.99208 -1.02173]
# D_triu
# [[        nan 2.02213e+00 2.97934e-03 2.01242e+00 1.49631e+00 1.88385e-03
#   2.01193e+00]
#  [        nan         nan 2.02510e+00 9.70248e-03 3.51844e+00 2.02401e+00
#   1.01922e-02]
#  [        nan         nan         nan 2.01540e+00 1.49334e+00 1.09548e-03
#   2.01491e+00]
#  [        nan         nan         nan         nan 3.50874e+00 2.01431e+00
#   4.89752e-04]
#  [        nan         nan         nan         nan         nan 1.49443e+00
#   3.50825e+00]
#  [        nan         nan         nan         nan         nan         nan
#   2.01382e+00]
#  [        nan         nan         nan         nan         nan         nan
#           nan]]
# [ 0.99078 -1.02895  0.99279 -1.02282  2.48651  0.99208]
# D_triu
# [[        nan 2.01973e+00 2.01118e-03 2.01360e+00 1.49573e+00 1.30366e-03]
#  [        nan         nan 2.02174e+00 6.13069e-03 3.51547e+00 2.02104e+00]
#  [        nan         nan         nan 2.01561e+00 1.49372e+00 7.07525e-04]
#  [        nan         nan         nan         nan 3.50934e+00 2.01491e+00]
#  [        nan         nan         nan         nan         nan 1.49443e+00]
#  [        nan         nan         nan         nan         nan         nan]]
# [ 0.99117 -1.0271   0.99208 -1.02322  2.48651]
# D_triu
# [[        nan 2.01826e+00 9.16637e-04 2.01439e+00 1.49535e+00]
#  [        nan         nan 2.01918e+00 3.87220e-03 3.51361e+00]
#  [        nan         nan         nan 2.01531e+00 1.49443e+00]
#  [        nan         nan         nan         nan 3.50974e+00]
#  [        nan         nan         nan         nan         nan]]
# [ 0.99208 -1.02589 -1.02352  2.48651]
# D_triu
# [[        nan 2.01797e+00 2.01560e+00 1.49443e+00]
#  [        nan         nan 2.36880e-03 3.51240e+00]
#  [        nan         nan         nan 3.51004e+00]
#  [        nan         nan         nan         nan]]
# [ 0.99208 -1.02393  2.48651]
# D_triu
# [[    nan 2.01601 1.49443]
#  [    nan     nan 3.51044]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 2.01601     nan]
#  [    nan     nan 3.51044]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan     nan     nan]
#  [    nan     nan 3.51044]
#  [    nan     nan     nan]]
# I move on to the check other masses
# [ 0.99208 -1.02393  2.48651]
# D_triu
# [[    nan 2.01601 1.49443]
#  [    nan     nan 3.51044]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 2.01601     nan]
#  [    nan     nan 3.51044]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan     nan     nan]
#  [    nan     nan 3.51044]
#  [    nan     nan     nan]]
# I move on to the check other masses
#   variable     value
# 0     c1,1  2.493435
# 1     c1,2  1.022547
# 2     c1,3 -0.991051
# 3    beta1  0.281123
# 0     c1,1  2.478409
# 1     c1,2  0.959275
# 2     c1,3 -0.976927
# 3    beta1  0.301658
# 0     c1,1  2.473702
# 1     c1,2  1.057495
# 2     c1,3 -1.107618
# 3    beta1  0.310936
# 0     c1,1  2.486513
# 1     c1,2  0.992081
# 2     c1,3 -1.023928
# 3    beta1  0.325579
#         MSE   MSE_log  Chi-Squared-Error
# 0  3.871158  0.183004           0.621896
# 1  4.404255  0.203638           0.720961
# 2  3.976687  0.212335           0.721894
# 3  4.125000  0.226961           0.775015
# [-0.90685  1.0203   1.02605 -0.92654 -0.9273  -0.91523 -0.90793 -0.92481
#   2.50823  2.50018]
#  [        nan         nan         nan         nan 2.10924e-03 3.42145e+00
#   3.41707e+00]
#  [        nan         nan         nan         nan         nan 3.41934e+00
#   3.41496e+00]
#  [        nan         nan         nan         nan         nan         nan
#   4.37764e-03]
#  [        nan         nan         nan         nan         nan         nan
#           nan]]
# [-0.91446  1.02479  1.02605 -0.916    2.50376  2.50018]
# D_triu
# [[        nan 1.93925e+00 1.94051e+00 1.53563e-03 3.41822e+00 3.41464e+00]
#  [        nan         nan 1.26047e-03 1.94079e+00 1.47897e+00 1.47539e+00]
#  [        nan         nan         nan 1.94205e+00 1.47771e+00 1.47413e+00]
#  [        nan         nan         nan         nan 3.41976e+00 3.41618e+00]
#  [        nan         nan         nan         nan         nan 3.58274e-03]
#  [        nan         nan         nan         nan         nan         nan]]
# [-0.91455  1.02605 -0.91546  2.50309  2.50018]
# D_triu
# [[        nan 1.94060e+00 9.09608e-04 3.41764e+00 3.41473e+00]
#  [        nan         nan 1.94151e+00 1.47704e+00 1.47413e+00]
#  [        nan         nan         nan 3.41855e+00 3.41564e+00]
#  [        nan         nan         nan         nan 2.91035e-03]
#  [        nan         nan         nan         nan         nan]]
# [-0.91466  1.02605  2.50254  2.50018]
# D_triu
# [[        nan 1.94071e+00 3.41720e+00 3.41484e+00]
#  [        nan         nan 1.47649e+00 1.47413e+00]
#  [        nan         nan         nan 2.36035e-03]
#  [        nan         nan         nan         nan]]
# [-0.91466  1.02605  2.50018]
# D_triu
# [[    nan 1.94071 3.41484]
#  [    nan     nan 1.47413]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 1.94071 3.41484]
#  [    nan     nan     nan]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan     nan 3.41484]
#  [    nan     nan     nan]
#  [    nan     nan     nan]]
# I move on to the check other masses
# [-0.91466  1.02605  2.50018]
# D_triu
# [[    nan 1.94071 3.41484]
#  [    nan     nan 1.47413]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan 1.94071 3.41484]
#  [    nan     nan     nan]
#  [    nan     nan     nan]]
# I move on to the check other masses
# D_triu
# [[    nan     nan 3.41484]
#  [    nan     nan     nan]
#  [    nan     nan     nan]]
# I move on to the check other masses
#   variable     value
# 0     c1,1  2.493435
# 1     c1,2  1.022547
# 2     c1,3 -0.991051
# 3    beta1  0.281123
# 0     c1,1  2.478409
# 1     c1,2  0.959275
# 2     c1,3 -0.976927
# 3    beta1  0.301658
# 0     c1,1  2.473702
# 1     c1,2  1.057495
# 2     c1,3 -1.107618
# 3    beta1  0.310936
# 0     c1,1  2.486513
# 1     c1,2  0.992081
# 2     c1,3 -1.023928
# 3    beta1  0.325579
# 0     c1,1  2.500175
# 1     c1,2  1.026049
# 2     c1,3 -0.914660
# 3    beta1  0.267333
#         MSE   MSE_log  Chi-Squared-Error
# 0  3.871158  0.183004           0.621896
# 1  4.404255  0.203638           0.720961
# 2  3.976687  0.212335           0.721894
# 3  4.125000  0.226961           0.775015
# 4  4.176970  0.211319           0.689962

# %%
filename = 'results3_POI' + '.csv'
results3_POI.to_csv('output/comparison_state_of_art/Poisson_GLMMDRE_output/' + filename)

filename = 'melt_POI' +'.csv'
melt_POI.to_csv('output/comparison_state_of_art/Poisson_GLMMDRE_output/' + filename)
